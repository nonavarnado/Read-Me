# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %%
filepath = r"Meridian_05-01-2022_05-30-2022_Hist_f67d4c7526d6.xlsx"
df = pd.read_excel(filepath)

df.columns
# Out:
# Index(['Date', 'Inverter 1A|AC Power|kW|Avg', 'Inverter 1B|AC Power|kW|Avg',
#        'Inverter 1C|AC Power|kW|Avg', 'Inverter 1D|AC Power|kW|Avg',
#        'Inverter 1E|AC Power|kW|Avg', 'Inverter 1F|AC Power|kW|Avg',
#        'Inverter 1G|AC Power|kW|Avg', 'Inverter 2A|AC Power|kW|Avg',
#        'Inverter 2B|AC Power|kW|Avg', 'Inverter 2C|AC Power|kW|Avg',
#        'Inverter 2D|AC Power|kW|Avg', 'Inverter 2E|AC Power|kW|Avg',
#        'Inverter 2F|AC Power|kW|Avg', 'Inverter 2G|AC Power|kW|Avg',
#        'Inverter 3A|AC Power|kW|Avg', 'Inverter 3B|AC Power|kW|Avg',
#        'Inverter 3C|AC Power|kW|Avg', 'Inverter 3D|AC Power|kW|Avg',
#        'Inverter 3E|AC Power|kW|Avg', 'Inverter 3F|AC Power|kW|Avg',
#        'Inverter 3G|AC Power|kW|Avg', 'Inverter 4A|AC Power|kW|Avg',
#        'Inverter 4B|AC Power|kW|Avg', 'Inverter 4C|AC Power|kW|Avg',
#        'Inverter 4D|AC Power|kW|Avg', 'Inverter 4E|AC Power|kW|Avg',
# ...

# %%
df.Date = pd.to_datetime(df.Date, utc=True, format=r"%m/%d/%Y %H:%M:%S %z")
print(df.dtypes)
df.head
# Out:
# Date                                          datetime64[ns, UTC]
# Inverter 1A|AC Power|kW|Avg                               float64
# Inverter 1B|AC Power|kW|Avg                               float64
# Inverter 1C|AC Power|kW|Avg                               float64
# Inverter 1D|AC Power|kW|Avg                               float64
# Inverter 1E|AC Power|kW|Avg                               float64
# Inverter 1F|AC Power|kW|Avg                               float64
# Inverter 1G|AC Power|kW|Avg                               float64
# Inverter 2A|AC Power|kW|Avg                               float64
# Inverter 2B|AC Power|kW|Avg                               float64
# Inverter 2C|AC Power|kW|Avg                               float64
# Inverter 2D|AC Power|kW|Avg                               float64
# Inverter 2E|AC Power|kW|Avg                               float64
# Inverter 2F|AC Power|kW|Avg                               float64
# ...

# %%
#filter based on date for INV-1 Sum all averages and divide by four
df1 = df.groupby([df['Date'].dt.date])[
                                        'Inverter 1A|AC Power|kW|Avg',       
                                        'Inverter 1B|AC Power|kW|Avg',                         
                                        'Inverter 1C|AC Power|kW|Avg',                               
                                        'Inverter 1D|AC Power|kW|Avg',                               
                                        'Inverter 1E|AC Power|kW|Avg',                               
                                        'Inverter 1F|AC Power|kW|Avg',                               
                                        'Inverter 1G|AC Power|kW|Avg',                              
                                        'Inverter 2A|AC Power|kW|Avg',                               
                                        'Inverter 2B|AC Power|kW|Avg',                               
                                        'Inverter 2C|AC Power|kW|Avg',                               
                                        'Inverter 2D|AC Power|kW|Avg',                               
                                        'Inverter 2E|AC Power|kW|Avg',                               
                                        'Inverter 2F|AC Power|kW|Avg',                               
                                        'Inverter 2G|AC Power|kW|Avg',                               
                                        'Inverter 3A|AC Power|kW|Avg',                               
                                        'Inverter 3B|AC Power|kW|Avg',                               
                                        'Inverter 3C|AC Power|kW|Avg',                               
                                        'Inverter 3D|AC Power|kW|Avg',                               
                                        'Inverter 3E|AC Power|kW|Avg',                              
                                        'Inverter 3F|AC Power|kW|Avg',                               
                                        'Inverter 3G|AC Power|kW|Avg',                              
                                        'Inverter 4A|AC Power|kW|Avg',                               
                                        'Inverter 4B|AC Power|kW|Avg',                               
                                        'Inverter 4C|AC Power|kW|Avg',                               
                                        'Inverter 4D|AC Power|kW|Avg',                              
                                        'Inverter 4E|AC Power|kW|Avg',                               
                                        'Inverter 4F|AC Power|kW|Avg',                              
                                        'Inverter 4G|AC Power|kW|Avg',                               
                                        'Inverter 5A|AC Power|kW|Avg',                               
                                        'Inverter 5B|AC Power|kW|Avg',                               
                                        'Inverter 5C|AC Power|kW|Avg',                              
                                        'Inverter 5D|AC Power|kW|Avg',                              
                                        'Inverter 5F|AC Power|kW|Avg',                               
                                        'Inverter 6A|AC Power|kW|Avg',                              
                                        'Inverter 6B|AC Power|kW|Avg',                              
                                        'Inverter 6C|AC Power|kW|Avg',                              
                                        'Inverter 6D|AC Power|kW|Avg',                              
                                        'Inverter 6E|AC Power|kW|Avg',                              
                                        'Inverter 6F|AC Power|kW|Avg',                              
                                        'Inverter 6G|AC Power|kW|Avg',                              
                                        'Inverter 7A|AC Power|kW|Avg',                               
                                        'Inverter 7B|AC Power|kW|Avg',                              
                                        'Inverter 7C|AC Power|kW|Avg',                               
                                        'Inverter 7D|AC Power|kW|Avg',                              
                                        'Inverter 7E|AC Power|kW|Avg',                              
                                        'Inverter 7F|AC Power|kW|Avg',                               
                                        'Inverter 7G|AC Power|kW|Avg',                              
                                        'Inverter 8A|AC Power|kW|Avg',                              
                                        'Inverter 8B|AC Power|kW|Avg',                               
                                        'Inverter 8C|AC Power|kW|Avg',                               
                                        'Inverter 8D|AC Power|kW|Avg',                            
                                        'Inverter 8E|AC Power|kW|Avg',                            
                                        'Main Meter|Power Output_RIG|MW|Avg',                      
                                        'Met Station|POA CMP11 Irradiance|Wh/m²|Avg'].sum().div(4)

df1
# Out:
# /var/folders/z7/vjcmj2hj0xs_chvr51mghx380000gn/T/ipykernel_3853/3376248111.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = df.groupby([df['Date'].dt.date])[
#             Inverter 1A|AC Power|kW|Avg  Inverter 1B|AC Power|kW|Avg  \
# Date
# 2022-05-01                   174.313000                     0.000000
# 2022-05-02                   174.745916                     0.000000
# 2022-05-03                   166.668000                   156.726750
# 2022-05-04                   196.048750                   234.564583
# 2022-05-05                   190.779416                   226.712666
# 2022-05-06                   191.595666                   228.896416
# 2022-05-07                   195.065166                   231.987166
# 2022-05-08                   120.973500                   135.197000
# 2022-05-09                   170.696499                   195.476083
# ...

# %%
#correct units *1000 for KW METER and divide by 1000 for KW POA values
print(df1['Main Meter|Power Output_RIG|MW|Avg']*1000)
# Out:
# Date
# 2022-05-01     8536.499675
# 2022-05-02     8068.916150
# 2022-05-03     8587.082900
# 2022-05-04    10248.499625
# 2022-05-05     8901.916200
# 2022-05-06     8501.666175
# 2022-05-07     8498.582875
# 2022-05-08     5039.499550
# 2022-05-09     7333.249525
# 2022-05-10     8576.666175
# 2022-05-11     8988.499500
# 2022-05-12     8773.749500
# 2022-05-13     8429.582925
# 2022-05-14     8434.082800
# 2022-05-15     6382.832800
# 2022-05-16     8433.749500
# 2022-05-17     7564.916175
# 2022-05-18     7939.499500
# 2022-05-19     7586.499500
# 2022-05-20     2612.499600
# 2022-05-21     7048.916200
# 2022-05-22     7888.332850
# 2022-05-23     8032.082850
# 2022-05-24     9560.999500
# 2022-05-25    11186.082925
# 2022-05-26    10828.416125
# 2022-05-27     8668.916200
# 2022-05-28     4666.749550
# 2022-05-29     9884.166250
# 2022-05-30     9069.249550
# 2022-05-31      596.749900
# Name: Main Meter|Power Output_RIG|MW|Avg, dtype: float64

# %%
print(df1['Met Station|POA CMP11 Irradiance|Wh/m²|Avg'].div(1000))
# Out:
# Date
# 2022-05-01    7.708406
# 2022-05-02    7.162276
# 2022-05-03    6.989577
# 2022-05-04    8.349439
# 2022-05-05    8.363974
# 2022-05-06    8.192914
# 2022-05-07    8.235744
# 2022-05-08    4.826641
# 2022-05-09    7.155819
# 2022-05-10    8.150839
# 2022-05-11    8.514423
# 2022-05-12    8.549212
# 2022-05-13    8.456907
# 2022-05-14    8.558315
# 2022-05-15    6.828129
# 2022-05-16    8.245202
# 2022-05-17    7.202789
# 2022-05-18    7.620519
# 2022-05-19    7.252779
# 2022-05-20    2.283512
# 2022-05-21    7.044016
# 2022-05-22    7.801631
# 2022-05-23    8.193096
# 2022-05-24    8.276888
# 2022-05-25    8.245311
# 2022-05-26    8.076252
# 2022-05-27    6.497117
# 2022-05-28    3.352486
# 2022-05-29    7.531617
# 2022-05-30    7.004294
# 2022-05-31    0.472447
# Name: Met Station|POA CMP11 Irradiance|Wh/m²|Avg, dtype: float64

# %%
#check for corrected units
df1
# Out:
#             Inverter 1A|AC Power|kW|Avg  Inverter 1B|AC Power|kW|Avg  \
# Date
# 2022-05-01                   174.313000                     0.000000
# 2022-05-02                   174.745916                     0.000000
# 2022-05-03                   166.668000                   156.726750
# 2022-05-04                   196.048750                   234.564583
# 2022-05-05                   190.779416                   226.712666
# 2022-05-06                   191.595666                   228.896416
# 2022-05-07                   195.065166                   231.987166
# 2022-05-08                   120.973500                   135.197000
# 2022-05-09                   170.696499                   195.476083
# 2022-05-10                   195.642500                   233.021583
# 2022-05-11                   195.620250                   244.693250
# 2022-05-12                   200.604083                   230.918083
# ...

# %%
df1.to_excel("Meridian_May22_DataTable.xlsx")
